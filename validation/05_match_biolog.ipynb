# %%
import gempipe

from helper_functions import *

# %%
tools = ['gempipe', 'gempipe_rf', 'carveme', 'bactabolize', 'gapseq']

# %% [markdown]
# # Main functions

# %%
def match_biolog_data(dataset, tools):
    
    # mach biolog sims with experimental data
    
    
    # import experimental data:
    df_match = pnd.read_csv(f'{dataset}/tables/biolog_exp.csv', index_col=0)
    biolog_mappings = get_biolog_C_mappings()
    

    for tool in tools: 
        df_match[f'model_value_{tool}'] = None
        df_match[f'call_{tool}'] = None


    # iterate through each strain:
    for tool, biolog_sims in zip(tools, [
        glob.glob(f'{dataset}/tools_runs/gempipe/output/biolog/*.csv'), 
        glob.glob(f'{dataset}/tools_runs/gempipe_rf/output/biolog/*.csv'), 
        glob.glob(f'{dataset}/tools_runs/carveme/biolog_sims/*.csv'), 
        glob.glob(f'{dataset}/tools_runs/bactabolize/biolog_sims/*.csv'),
        glob.glob(f'{dataset}/tools_runs/gapseq/biolog_sims/*.csv'),
    ]):

        for ss_biolog in biolog_sims:
            # load the simulations
            strain_id = Path(ss_biolog).stem 
            strain_id = strain_id.replace('_model', '')
            ss_biolog = pnd.read_csv(ss_biolog, index_col=0)


            # fill the table:
            cnt = 0
            for index, row in df_match.iterrows():
                if row['strain'] == strain_id:
                    substrate = row['substrate']


                    # extract the corresponding row from simulations:
                    match = ss_biolog[(ss_biolog['substrate']==substrate) & (ss_biolog['source']=='C')].iloc[0]


                    model_value_tool = None

                    if substrate in biolog_mappings[biolog_mappings['BiGG_exchange'].notna()].index:
                        model_value_tool = 0
                    if match['growth']==True:  model_value_tool = 1 
                    if match['growth']==False: model_value_tool = 0 

                    df_match.loc[index, f'model_value_{tool}'] = model_value_tool 


                    # track TP / TN / FP / FN looking at 'growth_call':
                    if model_value_tool != None:
                        if model_value_tool == row['growth_call'] and row['growth_call'] == 1:
                            df_match.loc[index, f'call_{tool}'] = 'TP' 
                            cnt += 1

                        elif model_value_tool == row['growth_call'] and row['growth_call'] == 0:
                            df_match.loc[index, f'call_{tool}'] = 'TN' 
                            cnt += 1

                        elif model_value_tool != row['growth_call'] and row['growth_call'] == 0:
                            df_match.loc[index, f'call_{tool}'] = 'FP' 
                            cnt += 1

                        elif model_value_tool != row['growth_call'] and row['growth_call'] == 1:
                            df_match.loc[index, f'call_{tool}'] = 'FN' 
                            cnt += 1


                    if match['status']=='infeasible':
                        df_match.loc[index, f'call_{tool}'] = 'infeasible' 

            print(tool, '\t', strain_id, '\t', cnt)
 
    return df_match

# %%
def get_FN_counts(dataset, df_match):
    # get FN counts; consider also the pan-model's Biolog sims
    
    # load pan-model's Biolog sims:
    biolog_panmodel = pnd.read_csv(f'{dataset}/tools_runs/gempipe/output/biolog_panmodel.csv', index_col=0)
    biolog_mappings = get_biolog_C_mappings()


    # try to understand FN mismatches
    fns_all = df_match.copy()
    fns_all = fns_all[(fns_all['growth_call']==1) & (fns_all['call_gempipe']=='FN')]
    fns_all = fns_all[['substrate', 'growth_call', 'call_gempipe']]
    fns = fns_all.drop_duplicates().copy()


    # count the number of occurences
    fns['counter'] = None
    for index, row in fns.iterrows():
        group = fns_all[fns_all['substrate']==row['substrate']]
        fns.loc[index, 'counter'] = len(group)
    fns = fns.sort_values('counter', ascending=False)


    # add the corresponding EX reaction: 
    fns['exr'] = None
    for index, row in fns.iterrows():
        substrate = row['substrate']
        fns.loc[index, 'exr'] = biolog_mappings.loc[substrate, 'BiGG_exchange'] 


    # test if the panmodel can grow or not
    fns['pan_growth'] = None
    for index, row in fns.iterrows(): 
        substrate = row['substrate']
        match = biolog_panmodel[(biolog_panmodel['substrate']==substrate) & (biolog_panmodel['source']=='C')].iloc[0]
        fns.loc[index, f'pan_growth'] = match['value']

    fns = fns.reset_index(drop=True)
    fns = fns.set_index('substrate', drop=True)
    
    return fns

# %% [markdown]
# # 01_klebsiella

# %%
df_match = match_biolog_data(dataset='01_klebsiella', tools=tools)
df_match.to_csv('01_klebsiella/tables/biolog_match.csv')
df_match
# Out:
# gempipe 	 Kvt_CDC4241_71 	 90
# gempipe 	 Kp_KP13 	 90
# gempipe 	 Kp_04A025 	 90
# gempipe 	 Kqs_07A044T 	 90
# gempipe 	 Ka_200023T 	 90
# gempipe 	 Kp_BJ1 	 90
# gempipe 	 Kqq_SB98 	 90
# gempipe 	 Kp_SB1067 	 90
# gempipe 	 Kvv_F2R9T 	 90
# gempipe 	 Kp_SA12 	 90
# gempipe 	 Kp_SB1139 	 90
# gempipe 	 Kp_MGH78578 	 90
# gempipe 	 Kvv_342 	 90
# gempipe 	 Kqs_CIP110288 	 90
# gempipe 	 Kp_NJST258_1 	 90
# gempipe 	 Kqq_18A069 	 90
# gempipe 	 Kp_SB611 	 90
# gempipe 	 Kp_T69 	 90
# gempipe 	 Kp_SB617 	 90
# gempipe 	 Kvv_01A065 	 90
# gempipe 	 Kp_SB1170 	 89
# gempipe 	 Kp_SB615 	 90
# gempipe 	 Kp_SB2390 	 90
# gempipe 	 Kp_SB612 	 90
# gempipe 	 Kp_NTUHK2044 	 90
# gempipe 	 Kp_CIP52.145 	 90
# gempipe 	 Kqv_08A119 	 90
# gempipe 	 Kqs_09A323 	 90
# gempipe 	 Kp_CG43 	 90
# gempipe 	 Kp_SA1 	 90
# gempipe 	 Kqs_12A476 	 90
# gempipe 	 Kqq_U41 	 90
# gempipe 	 Kqq_SB1124 	 90
# gempipe 	 Kqq_01A030T 	 90
# gempipe 	 Kp_03_9138_2 	 90
# gempipe 	 Kvv_At_22 	 90
# gempipe 	 Kqs_SB610 	 90
# gempipe_rf 	 Kvt_CDC4241_71 	 90
# gempipe_rf 	 Kp_KP13 	 90
# gempipe_rf 	 Kp_04A025 	 90
# gempipe_rf 	 Kqs_07A044T 	 90
# gempipe_rf 	 Ka_200023T 	 90
# gempipe_rf 	 Kp_BJ1 	 90
# gempipe_rf 	 Kqq_SB98 	 90
# gempipe_rf 	 Kp_SB1067 	 90
# gempipe_rf 	 Kvv_F2R9T 	 90
# gempipe_rf 	 Kp_SA12 	 90
# gempipe_rf 	 Kp_SB1139 	 90
# gempipe_rf 	 Kp_MGH78578 	 90
# gempipe_rf 	 Kvv_342 	 90
# gempipe_rf 	 Kqs_CIP110288 	 90
# gempipe_rf 	 Kp_NJST258_1 	 90
# gempipe_rf 	 Kqq_18A069 	 90
# gempipe_rf 	 Kp_SB611 	 90
# gempipe_rf 	 Kp_T69 	 90
# gempipe_rf 	 Kp_SB617 	 90
# gempipe_rf 	 Kvv_01A065 	 90
# gempipe_rf 	 Kp_SB1170 	 89
# gempipe_rf 	 Kp_SB615 	 90
# gempipe_rf 	 Kp_SB2390 	 90
# gempipe_rf 	 Kp_SB612 	 90
# gempipe_rf 	 Kp_NTUHK2044 	 90
# gempipe_rf 	 Kp_CIP52.145 	 90
# gempipe_rf 	 Kqv_08A119 	 90
# gempipe_rf 	 Kqs_09A323 	 90
# gempipe_rf 	 Kp_CG43 	 90
# gempipe_rf 	 Kp_SA1 	 90
# gempipe_rf 	 Kqs_12A476 	 90
# gempipe_rf 	 Kqq_U41 	 90
# gempipe_rf 	 Kqq_SB1124 	 90
# gempipe_rf 	 Kqq_01A030T 	 90
# gempipe_rf 	 Kp_03_9138_2 	 90
# gempipe_rf 	 Kvv_At_22 	 90
# gempipe_rf 	 Kqs_SB610 	 90
# carveme 	 Kvt_CDC4241_71 	 90
# carveme 	 Kp_KP13 	 90
# carveme 	 Kp_04A025 	 90
# carveme 	 Kqs_07A044T 	 90
# carveme 	 Ka_200023T 	 90
# carveme 	 Kp_BJ1 	 90
# carveme 	 Kqq_SB98 	 90
# carveme 	 Kp_SB1067 	 90
# carveme 	 Kvv_F2R9T 	 90
# carveme 	 Kp_SA12 	 90
# carveme 	 Kp_SB1139 	 90
# carveme 	 Kp_MGH78578 	 90
# carveme 	 Kvv_342 	 90
# carveme 	 Kqs_CIP110288 	 90
# carveme 	 Kp_NJST258_1 	 90
# carveme 	 Kqq_18A069 	 90
# carveme 	 Kp_SB611 	 90
# carveme 	 Kp_T69 	 90
# carveme 	 Kp_SB617 	 90
# carveme 	 Kvv_01A065 	 90
# carveme 	 Kp_SB1170 	 89
# carveme 	 Kp_SB615 	 90
# carveme 	 Kp_SB2390 	 90
# carveme 	 Kp_SB612 	 90
# carveme 	 Kp_NTUHK2044 	 90
# carveme 	 Kp_CIP52.145 	 90
# carveme 	 Kqv_08A119 	 90
# carveme 	 Kqs_09A323 	 90
# carveme 	 Kp_CG43 	 90
# carveme 	 Kp_SA1 	 90
# carveme 	 Kqs_12A476 	 90
# carveme 	 Kqq_U41 	 90
# carveme 	 Kqq_SB1124 	 90
# carveme 	 Kqq_01A030T 	 90
# carveme 	 Kp_03_9138_2 	 90
# carveme 	 Kvv_At_22 	 90
# carveme 	 Kqs_SB610 	 90
# bactabolize 	 Kp_SB612 	 90
# bactabolize 	 Kqs_07A044T 	 90
# bactabolize 	 Kp_SB617 	 90
# bactabolize 	 Kp_NJST258_1 	 90
# bactabolize 	 Kvv_F2R9T 	 90
# bactabolize 	 Kp_SB1170 	 89
# bactabolize 	 Ka_200023T 	 90
# bactabolize 	 Kp_T69 	 90
# bactabolize 	 Kp_SB1067 	 90
# bactabolize 	 Kqq_01A030T 	 90
# bactabolize 	 Kp_SB1139 	 90
# bactabolize 	 Kp_KP13 	 90
# bactabolize 	 Kp_MGH78578 	 90
# bactabolize 	 Kvv_342 	 90
# bactabolize 	 Kp_CG43 	 90
# bactabolize 	 Kp_SB2390 	 90
# bactabolize 	 Kp_BJ1 	 90
# bactabolize 	 Kqq_18A069 	 90
# bactabolize 	 Kqq_SB98 	 90
# bactabolize 	 Kvv_01A065 	 90
# bactabolize 	 Kp_SB611 	 90
# bactabolize 	 Kqq_U41 	 90
# bactabolize 	 Kp_SB615 	 90
# bactabolize 	 Kvt_CDC4241_71 	 90
# bactabolize 	 Kqs_12A476 	 90
# bactabolize 	 Kp_NTUHK2044 	 90
# bactabolize 	 Kp_04A025 	 90
# bactabolize 	 Kqs_09A323 	 90
# bactabolize 	 Kp_03_9138_2 	 90
# bactabolize 	 Kp_SA1 	 90
# bactabolize 	 Kvv_At_22 	 90
# bactabolize 	 Kqv_08A119 	 90
# bactabolize 	 Kqs_SB610 	 90
# bactabolize 	 Kqs_CIP110288 	 90
# bactabolize 	 Kqq_SB1124 	 90
# bactabolize 	 Kp_SA12 	 90
# bactabolize 	 Kp_CIP52.145 	 90
# gapseq 	 Kvt_CDC4241_71 	 90
# gapseq 	 Kp_KP13 	 90
# gapseq 	 Kp_04A025 	 90
# gapseq 	 Kqs_07A044T 	 90
# gapseq 	 Ka_200023T 	 90
# gapseq 	 Kp_BJ1 	 90
# gapseq 	 Kqq_SB98 	 90
# gapseq 	 Kp_SB1067 	 90
# gapseq 	 Kvv_F2R9T 	 90
# gapseq 	 Kp_SA12 	 90
# gapseq 	 Kp_SB1139 	 90
# gapseq 	 Kp_MGH78578 	 90
# gapseq 	 Kvv_342 	 90
# gapseq 	 Kqs_CIP110288 	 90
# gapseq 	 Kp_NJST258_1 	 90
# gapseq 	 Kqq_18A069 	 90
# gapseq 	 Kp_SB611 	 90
# gapseq 	 Kp_T69 	 90
# gapseq 	 Kp_SB617 	 90
# gapseq 	 Kvv_01A065 	 90
# gapseq 	 Kp_SB1170 	 89
# gapseq 	 Kp_SB615 	 90
# gapseq 	 Kp_SB2390 	 90
# gapseq 	 Kp_SB612 	 90
# gapseq 	 Kp_NTUHK2044 	 90
# gapseq 	 Kp_CIP52.145 	 90
# gapseq 	 Kqv_08A119 	 90
# gapseq 	 Kqs_09A323 	 90
# gapseq 	 Kp_CG43 	 90
# gapseq 	 Kp_SA1 	 90
# gapseq 	 Kqs_12A476 	 90
# gapseq 	 Kqq_U41 	 90
# gapseq 	 Kqq_SB1124 	 90
# gapseq 	 Kqq_01A030T 	 90
# gapseq 	 Kp_03_9138_2 	 90
# gapseq 	 Kvv_At_22 	 90
# gapseq 	 Kqs_SB610 	 90
#               strain               substrate  growth_call model_value_gempipe
# 2         Kvv_01A065  g-Amino-N-Butyric acid          1.0                   1  \
# 3         Kvv_01A065               L-Sorbose          1.0                   0
# 4         Kvv_01A065              Mucic acid          1.0                   1
# 5         Kvv_01A065     Tricarballylic acid          0.0                   0
# 8          Kp_SB1067  g-Amino-N-Butyric acid          1.0                   1
# ...              ...                     ...          ...                 ...
# 3473        Kp_SB612        Dihydroxyacetone          1.0                   1
# 3474        Kp_SB615        Dihydroxyacetone          1.0                   1
# 3475        Kp_SB617        Dihydroxyacetone          1.0                   1
# 3476  Kvt_CDC4241_71        Dihydroxyacetone          1.0                   1
# 3477        Kqq_SB98        Dihydroxyacetone          1.0                   1
#
#      call_gempipe model_value_gempipe_rf call_gempipe_rf model_value_carveme
# 2              TP                      1              TP                   1  \
# 3              FN                      0              FN                   0
# 4              TP                      1              TP                   1
# 5              TN                      0              TN                   1
# 8              TP                      1              TP                   1
# ...           ...                    ...             ...                 ...
# 3473           TP                      0              FN                   1
# 3474           TP                      0              FN                   1
# 3475           TP                      0              FN                   1
# 3476           TP                      0              FN                   1
# 3477           TP                      0              FN                   1
#
#      call_carveme model_value_bactabolize call_bactabolize model_value_gapseq
# 2              TP                       1               TP                  1  \
# 3              FN                       0               FN                  0
# 4              TP                       1               TP                  0
# 5              FP                       0               TN                  0
# 8              TP                       1               TP                  1
# ...           ...                     ...              ...                ...
# 3473           TP                       1               TP                  0
# 3474           TP                       1               TP                  0
# 3475           TP                       1               TP                  0
# 3476           TP                       1               TP                  0
# 3477           TP                       1               TP                  0
#
#      call_gapseq
# 2             TP
# 3             FN
# 4             FN
# 5             TN
# 8             TP
# ...          ...
# 3473          FN
# 3474          FN
# 3475          FN
# 3476          FN
# 3477          FN
#
# [3330 rows x 13 columns]

# %%
fns = get_FN_counts('01_klebsiella', df_match)
fns.to_csv('01_klebsiella/tables/biolog_fns.csv')
fns
# Out:
#                                  growth_call call_gempipe counter
# substrate
# Ala-Gly                                  1.0           FN      37  \
# Arbutin                                  1.0           FN      37
# Palatinose                               1.0           FN      37
# D-Raffinose                              1.0           FN      37
# Turanose                                 1.0           FN      37
# Tyramine                                 1.0           FN      36
# Gly-Pro                                  1.0           FN      35
# L-Sorbose                                1.0           FN      18
# Tricarballylic acid                      1.0           FN      15
# D-tagatose                               1.0           FN      14
# 5-Keto-D-Gluconic acid                   1.0           FN       9
# L-Lyxose                                 1.0           FN       5
# N-Acetyl-Neuraminic acid                 1.0           FN       5
# Propionic Acid                           1.0           FN       2
# L-Galactonic Acid-gamma-Lactone          1.0           FN       1
#
#                                              exr pan_growth
# substrate
# Ala-Gly                            EX_L_alagly_e        NaN
# Arbutin                                EX_arbt_e        0.0
# Palatinose                             EX_pala_e        NaN
# D-Raffinose                          EX_raffin_e        NaN
# Turanose                                EX_tur_e        NaN
# Tyramine                                EX_tym_e        0.0
# Gly-Pro                          EX_gly_pro__L_e        0.0
# L-Sorbose                            EX_srb__L_e        NaN
# Tricarballylic acid                     EX_tcb_e        NaN
# D-tagatose                           EX_tag__D_e        NaN
# 5-Keto-D-Gluconic acid               EX_5dglcn_e        0.0
# L-Lyxose                             EX_lyx__L_e  33.744853
# N-Acetyl-Neuraminic acid              EX_acnam_e  32.479465
# Propionic Acid                          EX_ppa_e        0.0
# L-Galactonic Acid-gamma-Lactone   EX_galctn__L_e  33.526514

# %% [markdown]
# # 02_ralstonia

# %%
df_match = match_biolog_data(dataset='02_ralstonia', tools=tools)
df_match.to_csv('02_ralstonia/tables/biolog_match.csv')
df_match
# Out:
# gempipe 	 K60 	 147
# gempipe 	 PSI07 	 147
# gempipe 	 PSS4 	 147
# gempipe 	 GMI1000 	 147
# gempipe 	 MOLK2 	 147
# gempipe 	 UW551 	 147
# gempipe 	 BDBR229 	 147
# gempipe 	 RUN2340 	 147
# gempipe 	 R24 	 147
# gempipe 	 BA7 	 147
# gempipe 	 CFBP2957 	 147
# gempipe_rf 	 K60 	 147
# gempipe_rf 	 PSI07 	 147
# gempipe_rf 	 PSS4 	 147
# gempipe_rf 	 GMI1000 	 147
# gempipe_rf 	 MOLK2 	 147
# gempipe_rf 	 UW551 	 147
# gempipe_rf 	 BDBR229 	 147
# gempipe_rf 	 RUN2340 	 147
# gempipe_rf 	 R24 	 147
# gempipe_rf 	 BA7 	 147
# gempipe_rf 	 CFBP2957 	 147
# carveme 	 K60 	 147
# carveme 	 PSI07 	 147
# carveme 	 PSS4 	 147
# carveme 	 GMI1000 	 147
# carveme 	 MOLK2 	 147
# carveme 	 UW551 	 147
# carveme 	 BDBR229 	 147
# carveme 	 RUN2340 	 147
# carveme 	 R24 	 147
# carveme 	 BA7 	 147
# carveme 	 CFBP2957 	 147
# bactabolize 	 UW551 	 147
# bactabolize 	 CFBP2957 	 147
# bactabolize 	 BDBR229 	 147
# bactabolize 	 GMI1000 	 147
# bactabolize 	 RUN2340 	 147
# bactabolize 	 PSI07 	 147
# bactabolize 	 R24 	 147
# bactabolize 	 K60 	 147
# bactabolize 	 BA7 	 147
# bactabolize 	 PSS4 	 147
# bactabolize 	 MOLK2 	 147
# gapseq 	 K60 	 147
# gapseq 	 PSI07 	 147
# gapseq 	 PSS4 	 147
# gapseq 	 GMI1000 	 147
# gapseq 	 MOLK2 	 147
# gapseq 	 UW551 	 147
# gapseq 	 BDBR229 	 147
# gapseq 	 RUN2340 	 147
# gapseq 	 R24 	 147
# gapseq 	 BA7 	 147
# gapseq 	 CFBP2957 	 147
#        strain             substrate  growth_call model_value_gempipe
# 0         BA7           L-Arabinose            0                   0  \
# 1        PSS4           L-Arabinose            0                   0
# 2     GMI1000           L-Arabinose            0                   0
# 3         R24           L-Arabinose            0                   0
# 4       PSI07           L-Arabinose            0                   0
# ...       ...                   ...          ...                 ...
# 2085    UW551  3-hydroxy-2-butanone            0                   0
# 2086    MOLK2  3-hydroxy-2-butanone            0                   0
# 2087  RUN2340  3-hydroxy-2-butanone            0                   0
# 2088      K60  3-hydroxy-2-butanone            0                   0
# 2089  BDBR229  3-hydroxy-2-butanone            0                   0
#
#      call_gempipe model_value_gempipe_rf call_gempipe_rf model_value_carveme
# 0              TN                      0              TN                   0  \
# 1              TN                      0              TN                   0
# 2              TN                      0              TN                   0
# 3              TN                      0              TN                   0
# 4              TN                      0              TN                   0
# ...           ...                    ...             ...                 ...
# 2085           TN                      0              TN                   0
# 2086           TN                      0              TN                   0
# 2087           TN                      0              TN                   0
# 2088           TN                      0              TN                   0
# 2089           TN                      0              TN                   0
#
#      call_carveme model_value_bactabolize call_bactabolize model_value_gapseq
# 0              TN                       0               TN                  1  \
# 1              TN                       0               TN                  1
# 2              TN                       0               TN                  1
# 3              TN                       0               TN                  1
# 4              TN                       0               TN                  1
# ...           ...                     ...              ...                ...
# 2085           TN                       0               TN                  0
# 2086           TN                       0               TN                  0
# 2087           TN                       0               TN                  0
# 2088           TN                       0               TN                  0
# 2089           TN                       0               TN                  0
#
#      call_gapseq
# 0             FP
# 1             FP
# 2             FP
# 3             FP
# 4             FP
# ...          ...
# 2085          TN
# 2086          TN
# 2087          TN
# 2088          TN
# 2089          TN
#
# [2090 rows x 13 columns]

# %%
fns = get_FN_counts('02_ralstonia', df_match)
fns.to_csv('02_ralstonia/tables/biolog_fns.csv')
fns
# Out:
#                                  growth_call call_gempipe counter
# substrate
# quinic acid                                1           FN      10  \
# pectin                                     1           FN       8
# Dihydroxyacetone                           1           FN       5
# N-Acetyl-D-Glucosamine                     1           FN       3
# p-Hydroxyphenyl Acetic acid                1           FN       3
# L-Galactonic Acid-gamma-Lactone            1           FN       3
# d-tartaric acid                            1           FN       2
# sebacic acid                               1           FN       2
# D-Aspartic Acid                            1           FN       2
# malonic acid                               1           FN       1
# hydroxy-l-proline                          1           FN       1
# n-acetyl-l-glutamic acid                   1           FN       1
# D-Sorbitol                                 1           FN       1
# D-Mannitol                                 1           FN       1
# b-hydroxybutyric acid                      1           FN       1
# D-Trehalose                                1           FN       1
# D-Malic Acid                               1           FN       1
# Ala-Gly                                    1           FN       1
# Glyoxylic Acid                             1           FN       1
# butyric acid                               1           FN       1
#
#                                             exr pan_growth
# substrate
# quinic acid                           EX_quin_e        NaN
# pectin                              EX_pectin_e        NaN
# Dihydroxyacetone                       EX_dha_e   1.698058
# N-Acetyl-D-Glucosamine               EX_acgam_e        NaN
# p-Hydroxyphenyl Acetic acid         EX_4hphac_e  20.936671
# L-Galactonic Acid-gamma-Lactone  EX_galctn__L_e        NaN
# d-tartaric acid                   EX_tartr__D_e        NaN
# sebacic acid                       EX_sebacid_e        NaN
# D-Aspartic Acid                     EX_asp__D_e        NaN
# malonic acid                         EX_malon_e        NaN
# hydroxy-l-proline                 EX_4hpro_LT_e        NaN
# n-acetyl-l-glutamic acid             EX_acglu_e        NaN
# D-Sorbitol                          EX_sbt__D_e  21.702193
# D-Mannitol                             EX_mnl_e  21.702193
# b-hydroxybutyric acid                  EX_bhb_e  13.040322
# D-Trehalose                            EX_tre_e  27.812641
# D-Malic Acid                        EX_mal__D_e        NaN
# Ala-Gly                           EX_L_alagly_e        NaN
# Glyoxylic Acid                         EX_glx_e        NaN
# butyric acid                           EX_but_e   12.78575

# %% [markdown]
# # 03_pseudomonas

# %%
df_match = match_biolog_data(dataset='03_pseudomonas', tools=tools)
df_match.to_csv('03_pseudomonas/tables/biolog_match.csv')
df_match
# Out:
# gempipe 	 ChPhzTR39 	 93
# gempipe 	 Q16 	 93
# gempipe 	 ChPhzTR18 	 93
# gempipe 	 PCM2210 	 93
# gempipe 	 DSM_19603 	 93
# gempipe 	 66 	 93
# gempipe 	 SLPH10 	 93
# gempipe 	 CW2 	 93
# gempipe 	 ATCC17411 	 93
# gempipe 	 449 	 93
# gempipe 	 K27 	 93
# gempipe 	 PA23 	 93
# gempipe 	 P2 	 93
# gempipe 	 DSM_21509 	 93
# gempipe 	 ChPhzS140 	 93
# gempipe 	 M71 	 93
# gempipe 	 DTR133 	 93
# gempipe 	 O6 	 93
# gempipe 	 PCL1607 	 93
# gempipe 	 ChPhzS24 	 93
# gempipe 	 ATCC17809 	 93
# gempipe 	 ChPhzS135 	 93
# gempipe 	 30-84 	 93
# gempipe 	 ToZa7 	 93
# gempipe 	 ATCC17415 	 93
# gempipe 	 ChPhzS23 	 93
# gempipe 	 464 	 93
# gempipe 	 PCL1391 	 93
# gempipe 	 ChPhzTR38 	 93
# gempipe 	 ChPhzTR44 	 93
# gempipe 	 TAMOak81 	 93
# gempipe 	 C50 	 93
# gempipe 	 DSM_6698 	 93
# gempipe 	 B25 	 93
# gempipe 	 Pb-St2 	 93
# gempipe 	 M12 	 93
# gempipe_rf 	 ChPhzTR39 	 93
# gempipe_rf 	 Q16 	 93
# gempipe_rf 	 ChPhzTR18 	 93
# gempipe_rf 	 PCM2210 	 93
# gempipe_rf 	 DSM_19603 	 93
# gempipe_rf 	 66 	 93
# gempipe_rf 	 SLPH10 	 93
# gempipe_rf 	 CW2 	 93
# gempipe_rf 	 ATCC17411 	 93
# gempipe_rf 	 449 	 93
# gempipe_rf 	 K27 	 93
# gempipe_rf 	 PA23 	 93
# gempipe_rf 	 P2 	 93
# gempipe_rf 	 DSM_21509 	 93
# gempipe_rf 	 ChPhzS140 	 93
# gempipe_rf 	 M71 	 93
# gempipe_rf 	 DTR133 	 93
# gempipe_rf 	 O6 	 93
# gempipe_rf 	 PCL1607 	 93
# gempipe_rf 	 ChPhzS24 	 93
# gempipe_rf 	 ATCC17809 	 93
# gempipe_rf 	 ChPhzS135 	 93
# gempipe_rf 	 30-84 	 93
# gempipe_rf 	 ToZa7 	 93
# gempipe_rf 	 ATCC17415 	 93
# gempipe_rf 	 ChPhzS23 	 93
# gempipe_rf 	 464 	 93
# gempipe_rf 	 PCL1391 	 93
# gempipe_rf 	 ChPhzTR38 	 93
# gempipe_rf 	 ChPhzTR44 	 93
# gempipe_rf 	 TAMOak81 	 93
# gempipe_rf 	 C50 	 93
# gempipe_rf 	 DSM_6698 	 93
# gempipe_rf 	 B25 	 93
# gempipe_rf 	 Pb-St2 	 93
# gempipe_rf 	 M12 	 93
# carveme 	 ChPhzTR39 	 93
# carveme 	 Q16 	 93
# carveme 	 ChPhzTR18 	 93
# carveme 	 PCM2210 	 93
# carveme 	 DSM_19603 	 93
# carveme 	 66 	 93
# carveme 	 SLPH10 	 93
# carveme 	 CW2 	 93
# carveme 	 ATCC17411 	 93
# carveme 	 449 	 93
# carveme 	 K27 	 93
# carveme 	 PA23 	 93
# carveme 	 P2 	 93
# carveme 	 DSM_21509 	 93
# carveme 	 ChPhzS140 	 93
# carveme 	 M71 	 93
# carveme 	 DTR133 	 93
# carveme 	 O6 	 93
# carveme 	 PCL1607 	 93
# carveme 	 ChPhzS24 	 93
# carveme 	 ATCC17809 	 93
# carveme 	 ChPhzS135 	 93
# carveme 	 30-84 	 93
# carveme 	 ToZa7 	 93
# carveme 	 ATCC17415 	 93
# carveme 	 ChPhzS23 	 93
# carveme 	 464 	 93
# carveme 	 PCL1391 	 93
# carveme 	 ChPhzTR38 	 93
# carveme 	 ChPhzTR44 	 93
# carveme 	 TAMOak81 	 93
# carveme 	 C50 	 93
# carveme 	 DSM_6698 	 93
# carveme 	 B25 	 93
# carveme 	 Pb-St2 	 93
# carveme 	 M12 	 93
# bactabolize 	 449 	 93
# bactabolize 	 ChPhzTR38 	 93
# bactabolize 	 ChPhzTR18 	 93
# bactabolize 	 ChPhzS140 	 93
# bactabolize 	 PA23 	 93
# bactabolize 	 ATCC17411 	 93
# bactabolize 	 TAMOak81 	 93
# bactabolize 	 DSM_21509 	 93
# bactabolize 	 M12 	 93
# bactabolize 	 PCM2210 	 93
# bactabolize 	 DTR133 	 93
# bactabolize 	 ToZa7 	 93
# bactabolize 	 Pb-St2 	 93
# bactabolize 	 CW2 	 93
# bactabolize 	 30-84 	 93
# bactabolize 	 B25 	 93
# bactabolize 	 K27 	 93
# bactabolize 	 464 	 93
# bactabolize 	 PCL1607 	 93
# bactabolize 	 ChPhzS24 	 93
# bactabolize 	 C50 	 93
# bactabolize 	 ATCC17809 	 93
# bactabolize 	 PCL1391 	 93
# bactabolize 	 ChPhzTR44 	 93
# bactabolize 	 ChPhzTR39 	 93
# bactabolize 	 SLPH10 	 93
# bactabolize 	 Q16 	 93
# bactabolize 	 ChPhzS135 	 93
# bactabolize 	 DSM_19603 	 93
# bactabolize 	 DSM_6698 	 93
# bactabolize 	 ChPhzS23 	 93
# bactabolize 	 O6 	 93
# bactabolize 	 M71 	 93
# bactabolize 	 66 	 93
# bactabolize 	 P2 	 93
# bactabolize 	 ATCC17415 	 93
# gapseq 	 ChPhzTR39 	 93
# gapseq 	 Q16 	 93
# gapseq 	 ChPhzTR18 	 93
# gapseq 	 PCM2210 	 93
# gapseq 	 DSM_19603 	 93
# gapseq 	 66 	 93
# gapseq 	 SLPH10 	 93
# gapseq 	 CW2 	 93
# gapseq 	 ATCC17411 	 93
# gapseq 	 449 	 93
# gapseq 	 K27 	 93
# gapseq 	 PA23 	 93
# gapseq 	 P2 	 93
# gapseq 	 DSM_21509 	 93
# gapseq 	 ChPhzS140 	 93
# gapseq 	 M71 	 93
# gapseq 	 DTR133 	 93
# gapseq 	 O6 	 93
# gapseq 	 PCL1607 	 93
# gapseq 	 ChPhzS24 	 93
# gapseq 	 ATCC17809 	 93
# gapseq 	 ChPhzS135 	 93
# gapseq 	 30-84 	 93
# gapseq 	 ToZa7 	 93
# gapseq 	 ATCC17415 	 93
# gapseq 	 ChPhzS23 	 93
# gapseq 	 464 	 93
# gapseq 	 PCL1391 	 93
# gapseq 	 ChPhzTR38 	 93
# gapseq 	 ChPhzTR44 	 93
# gapseq 	 TAMOak81 	 93
# gapseq 	 C50 	 93
# gapseq 	 DSM_6698 	 93
# gapseq 	 B25 	 93
# gapseq 	 Pb-St2 	 93
# gapseq 	 M12 	 93
#          strain               substrate  growth_call model_value_gempipe
# 0         30-84             L-Arabinose            1                   0  \
# 1     ATCC17415             L-Arabinose            1                   0
# 2      TAMOak81             L-Arabinose            0                   0
# 3     ATCC17411             L-Arabinose            0                   0
# 4     ATCC17809             L-Arabinose            0                   0
# ...         ...                     ...          ...                 ...
# 3955  ChPhzTR38  N-Acetyl-D-Mannosamine            1                   0
# 3956  ChPhzTR39  N-Acetyl-D-Mannosamine            1                   0
# 3957  ChPhzTR18  N-Acetyl-D-Mannosamine            1                   0
# 3958       PA23  N-Acetyl-D-Mannosamine            1                   0
# 3959         O6  N-Acetyl-D-Mannosamine            1                   0
#
#      call_gempipe model_value_gempipe_rf call_gempipe_rf model_value_carveme
# 0              FN                      0              FN                   0  \
# 1              FN                      0              FN                   0
# 2              TN                      0              TN                   0
# 3              TN                      0              TN                   0
# 4              TN                      0              TN                   0
# ...           ...                    ...             ...                 ...
# 3955           FN                      0              FN                   0
# 3956           FN                      0              FN                   0
# 3957           FN                      0              FN                   0
# 3958           FN                      0              FN                   0
# 3959           FN                      0              FN                   0
#
#      call_carveme model_value_bactabolize call_bactabolize model_value_gapseq
# 0              FN                       0               FN                  1  \
# 1              FN                       0               FN                  1
# 2              TN                       0               TN                  1
# 3              TN                       0               TN                  1
# 4              TN                       0               TN                  1
# ...           ...                     ...              ...                ...
# 3955           FN                       0               FN                  0
# 3956           FN                       0               FN                  0
# 3957           FN                       0               FN                  0
# 3958           FN                       0               FN                  0
# 3959           FN                       0               FN                  0
#
#      call_gapseq
# 0             TP
# 1             TP
# 2             FP
# 3             FP
# 4             FP
# ...          ...
# 3955          FN
# 3956          FN
# 3957          FN
# 3958          FN
# 3959          FN
#
# [3960 rows x 13 columns]

# %%
fns = get_FN_counts('03_pseudomonas', df_match)
fns.to_csv('03_pseudomonas/tables/biolog_fns.csv')
fns
# Out:
#                              growth_call call_gempipe counter
# substrate
# Ala-Gly                                1           FN      36  \
# D-Mannitol                             1           FN      36
# Tyramine                               1           FN      35
# n-acetyl-l-glutamic acid               1           FN      35
# N-Acetyl-D-Glucosamine                 1           FN      35
# m-Inositol                             1           FN      34
# p-Hydroxyphenyl Acetic acid            1           FN      34
# malonic acid                           1           FN      33
# N-Acetyl-D-Mannosamine                 1           FN      33
# D-Trehalose                            1           FN      32
# butyric acid                           1           FN      27
# Sucrose                                1           FN      27
# itaconic acid                          1           FN      26
# gly-glu                                1           FN      26
# D-Arabitol                             1           FN      24
# L-Arabinose                            1           FN      24
# D-Galactose                            1           FN      23
# D-Galactonic acid-g-Lactone            1           FN      23
# L-Lactic Acid                          1           FN      23
# n-acetyl-d-galactosamine               1           FN      20
# 5-Keto-D-Gluconic acid                 1           FN      16
# citramalic acid                        1           FN      13
# D-Glucosamine                          1           FN      13
# Gly-Pro                                1           FN      12
# D,L-a-Glycerol Phosphate               1           FN      11
# pectin                                 1           FN       9
# acetamide                              1           FN       9
# Formic Acid                            1           FN       6
# gly-asp                                1           FN       2
# quinic acid                            1           FN       1
# sebacic acid                           1           FN       1
# L-Tartaric Acid                        1           FN       1
# a-hydroxybutyric acid                  1           FN       1
# g-hydroxybutyric acid                  1           FN       1
# dextrin                                1           FN       1
# D-Aspartic Acid                        1           FN       1
#
#                                          exr pan_growth
# substrate
# Ala-Gly                        EX_L_alagly_e        NaN
# D-Mannitol                          EX_mnl_e        NaN
# Tyramine                            EX_tym_e        NaN
# n-acetyl-l-glutamic acid          EX_acglu_e        NaN
# N-Acetyl-D-Glucosamine            EX_acgam_e        NaN
# m-Inositol                        EX_inost_e        0.0
# p-Hydroxyphenyl Acetic acid      EX_4hphac_e  21.137468
# malonic acid                      EX_malon_e        NaN
# N-Acetyl-D-Mannosamine           EX_acmana_e        0.0
# D-Trehalose                         EX_tre_e  35.305359
# butyric acid                        EX_but_e        NaN
# Sucrose                            EX_sucr_e  35.305359
# itaconic acid                    EX_itacon_e        NaN
# gly-glu                      EX_gly_glu__L_e        NaN
# D-Arabitol                       EX_abt__D_e        NaN
# L-Arabinose                     EX_arab__L_e        NaN
# D-Galactose                         EX_gal_e        0.0
# D-Galactonic acid-g-Lactone   EX_galctn__D_e  26.682893
# L-Lactic Acid                    EX_lac__L_e  16.970461
# n-acetyl-d-galactosamine          EX_acgal_e        NaN
# 5-Keto-D-Gluconic acid           EX_5dglcn_e        NaN
# citramalic acid                    EX_citm_e        NaN
# D-Glucosamine                       EX_gam_e        0.0
# Gly-Pro                      EX_gly_pro__L_e        NaN
# D,L-a-Glycerol Phosphate         EX_glyc3p_e        0.0
# pectin                           EX_pectin_e        NaN
# acetamide                            EX_ad_e        NaN
# Formic Acid                         EX_for_e  11.921335
# gly-asp                      EX_gly_asp__L_e        NaN
# quinic acid                        EX_quin_e  17.893729
# sebacic acid                    EX_sebacid_e        NaN
# L-Tartaric Acid                EX_tartr__L_e        NaN
# a-hydroxybutyric acid               EX_2hb_e        NaN
# g-hydroxybutyric acid               EX_ghb_e        NaN
# dextrin                         EX_dextrin_e        NaN
# D-Aspartic Acid                  EX_asp__D_e        NaN

# %% [markdown]
# # Create supplementary table

# %%
res_dic = {}
for dataset in [
    '01_klebsiella',
    '02_ralstonia',
    '03_pseudomonas',
]:
    df_match = pnd.read_csv(f'{dataset}/tables/biolog_match.csv', index_col=0)
    
    # remove substrates never modeled by any of the tools
    for tool in ['gempipe', 'gempipe_rf', 'carveme', 'bactabolize', 'gapseq']:
        df_match = df_match[
            df_match[f'model_value_{tool}'].notna()
        ]
    
    res_dic[dataset] = {}
    for substrate in df_match['substrate'].unique():
        res_dic[dataset][substrate] = {} 
    
    for index, row in df_match.iterrows():
        
        try: values = [str(int(row['growth_call']))]
        except: values = ['?']
        
        for tool in ['gempipe', 'gempipe_rf', 'carveme', 'bactabolize', 'gapseq']:
            call = str(df_match.loc[index, f'call_{tool}'])
            if call=='infeasible': call = 'in' # shorter
            values = values + [call]
        
        res_dic[dataset][row['substrate']][row['strain']] = ','.join(values)

        
with pnd.ExcelWriter('tables/Supplementary File 1.xlsx', engine='xlsxwriter') as writer:
    
    
    INFO = """
        Comparison between experimental and simulated binarized Biolog® PM screenings. 
        Rows are substrates, columns are strains. 
        Cells follow the format “{E}-{T1}-{T2}-{T3}-{T4}-{T5}”, 
        where {E} is the experimental binary growth output (0: no growth; 1: growth); 
        {T1}, {T2}, {T3}, {T4}, {T5} are the matches of Gempipe, Gempipe (reference-free), CarveMe, Bactabolize and gapse, respectively.
        (“TP”: true positive; “TN”: true negative; “FP”: false positive; “FN”: false negative; “in”: infeasible FBA solution).
    """
    data = [i.strip().rstrip() for i in INFO.strip().rstrip().split('\n')]
    df = pnd.DataFrame(data, columns=["INFO"])
    df.to_excel(writer, sheet_name='INFO', index=False)
    
    for dataset in res_dic.keys():
        
        rows = []  # list of dicts
        for substrate in res_dic[dataset].keys():
            row = {}
            row['substrate'] = substrate
            for strain in res_dic[dataset][substrate].keys():
                row[strain] = res_dic[dataset][substrate][strain]
            rows.append(row)
                
        df =  pnd.DataFrame.from_records(rows)     
        df.to_excel(writer, sheet_name=dataset, index=False)
